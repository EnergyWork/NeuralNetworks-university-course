# %% [markdown]
# # Сегментация и токенизация

# %% [markdown]
# В этом ноутбуке демонстрируются функции сегментации на предложения и токенизации в `NLTK`, `spaCy` и `Stanza`.
# Сначала рассматриваются примеры для английского языка, в конце приводится код для русского.

# %% [markdown]
# ### Содержание:
# 1. [NLTK](#NLTK)
#     - [NLTK: сегментация на предложения](#NLTK:-сегментация-на-предложения)
#     - [NLTK: токенизация](#NLTK:-токенизация)
#     - [NLTK: работа со скобочными выражениями](#NLTK:-работа-со-скобочными-выражениями)
# 1. [spaCy](#spaCy)
#     - [spaCy: сегментация на предложения](#spaCy:-сегментация-на-предложения)
#         - [Вариант 1. Dependency parser](#Вариант-1.-Dependency-parser)
#         - [Вариант 2. Statistical sentence segmenter](#Вариант-2.-Statistical-sentence-segmenter)
#         - [Вариант 3. Rule-based pipeline component](#Вариант-3.-Rule-based-pipeline-component)
#         - [Вариант 4. Custom rule-based strategy](#Вариант-4.-Custom-rule-based-strategy)
#     - [spaCy: токенизация](#spaCy:-токенизация)
# 1. [Stanza](#Stanza)
#     - [Stanza: сегментация](#Stanza:-сегментация)
#     - [Stanza: токенизация](#Stanza:-токенизация)
# 1. [Сравнение](#Сравнение)
#     - [Сегментация](#Сегментация)
#     - [Токенизация](#Токенизация)
# 1. [Русский язык](#Русский-язык)
#     - [Natasha](#Natasha)
#     - [Русский язык: сегментация](#Русский-язык:-сегментация)
#     - [Русский язык: токенизация](#Русский-язык:-токенизация)

# %% [markdown]
# # NLTK

# %% [markdown]
# `nltk.tokenize` package: https://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize, SExprTokenizer

# %% [markdown]
# Эти функции требуют установленной модели `Punkt`.

# %% [markdown]
# Загрузка модулей и корпусов для NLTK (должно открыться специальное приложение):

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
texts = [
    'This is very simple sentence.',
    'This sentence, has comma!',
    'The first sentence. The second sentence.',
    'The first sentence.The second sentence without space.',
    'This sentence does not have a point at the end',
    "This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space. ",
    'An example with "quotes"',
    'An example with references [1], [2, 3], and this[4]',
    'This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith',
    'this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith',
    'An example with \n newline',
    'An example with dots... Between sentences...',
    'Another example with dots...without space... or with.',
    'An example with hyphen-based word, for example, Emilia-Romagna.',
    'Hyphen (or minus) on the -left and on the right- sides.',
    'Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%', 
    '@remy: This is waaaaayyyy too much for you!!!!!! :))) :(',
    'Good muffins cost $3.88\nin New York.  Please buy me... two of them.\n\nThanks.',
    '"An example with direct speech?" - said a developer',
    'Another example: "Direct speech, the dot before the quote." And next sentence.',
    'Third example: "The dot after the quote". And next sentence.'
]

# %% [markdown]
# #### NLTK: сегментация на предложения

# %%
for text in texts:
    sentences = sent_tokenize(text)
    print(text)
    for i, sentence in enumerate(sentences):
        print(f'\t{i}: {sentence}')
    print('\n')
# Out:
# This is very simple sentence.
# 	0: This is very simple sentence.
#
#
# This sentence, has comma!
# 	0: This sentence, has comma!
#
#
# The first sentence. The second sentence.
# 	0: The first sentence.
# 	1: The second sentence.
#
#
# The first sentence.The second sentence without space.
# 	0: The first sentence.The second sentence without space.
#
#
# This sentence does not have a point at the end
# 	0: This sentence does not have a point at the end
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# 	0: This sentence doesn't have an apostrophe... wait...
# 	1: It has word's apostrophe and double  space.
#
#
# An example with "quotes"
# 	0: An example with "quotes"
#
#
# An example with references [1], [2, 3], and this[4]
# 	0: An example with references [1], [2, 3], and this[4]
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# 	0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# 	0: this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
#
#
# An example with
#  newline
# 	0: An example with
#  newline
#
#
# An example with dots... Between sentences...
# 	0: An example with dots...
# 	1: Between sentences...
#
#
# Another example with dots...without space... or with.
# 	0: Another example with dots...without space... or with.
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# 	0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# 	0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# 	0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# 	0: @remy: This is waaaaayyyy too much for you!!!!!!
# 	1: :))) :(
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# 	0: Good muffins cost $3.88
# in New York.
# 	1: Please buy me... two of them.
# 	2: Thanks.
#
#
# "An example with direct speech?" - said a developer
# 	0: "An example with direct speech?"
# 	1: - said a developer
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# 	0: Another example: "Direct speech, the dot before the quote."
# 	1: And next sentence.
#
#
# Third example: "The dot after the quote". And next sentence.
# 	0: Third example: "The dot after the quote".
# 	1: And next sentence.

# %% [markdown]
# #### NLTK: токенизация

# %%
for text in texts:
    tokens = word_tokenize(text)
    print(text)
    print(tokens)
    print('\n')
# Out:
# This is very simple sentence.
# ['This', 'is', 'very', 'simple', 'sentence', '.']
#
#
# This sentence, has comma!
# ['This', 'sentence', ',', 'has', 'comma', '!']
#
#
# The first sentence. The second sentence.
# ['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', '.']
#
#
# The first sentence.The second sentence without space.
# ['The', 'first', 'sentence.The', 'second', 'sentence', 'without', 'space', '.']
#
#
# This sentence does not have a point at the end
# ['This', 'sentence', 'does', 'not', 'have', 'a', 'point', 'at', 'the', 'end']
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# ['This', 'sentence', 'does', "n't", 'have', 'an', 'apostrophe', '...', 'wait', '...', 'It', 'has', 'word', "'s", 'apostrophe', 'and', 'double', 'space', '.']
#
#
# An example with "quotes"
# ['An', 'example', 'with', '``', 'quotes', "''"]
#
#
# An example with references [1], [2, 3], and this[4]
# ['An', 'example', 'with', 'references', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'and', 'this', '[', '4', ']']
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# ['This', 'is', 'an', 'example', 'of', 'the', 'names', ':', 'J.', 'Smith', ',', 'J.Smith', ',', 'J.K.', 'Smith', ',', 'J.', 'K.', 'Smith', ',', 'John', 'K.', 'Smith', ',', 'John', 'K.Smith', ',', 'Mr.', 'Smith', ',', 'Mr.Smith']
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# ['this', 'is', 'an', 'example', 'of', 'the', 'names', 'with', 'lower', 'letters', ':', 'j.', 'smith', ',', 'j.smith', ',', 'j.k.', 'smith', ',', 'j.', 'k.', 'smith', ',', 'sohn', 'k.', 'smith', ',', 'john', 'k.smith', ',', 'mr.', 'smith', ',', 'mr.smith']
#
#
# An example with
#  newline
# ['An', 'example', 'with', 'newline']
#
#
# An example with dots... Between sentences...
# ['An', 'example', 'with', 'dots', '...', 'Between', 'sentences', '...']
#
#
# Another example with dots...without space... or with.
# ['Another', 'example', 'with', 'dots', '...', 'without', 'space', '...', 'or', 'with', '.']
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# ['An', 'example', 'with', 'hyphen-based', 'word', ',', 'for', 'example', ',', 'Emilia-Romagna', '.']
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# ['Hyphen', '(', 'or', 'minus', ')', 'on', 'the', '-left', 'and', 'on', 'the', 'right-', 'sides', '.']
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# ['Numbers', 'in', 'various', 'forms', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# ['@', 'remy', ':', 'This', 'is', 'waaaaayyyy', 'too', 'much', 'for', 'you', '!', '!', '!', '!', '!', '!', ':', ')', ')', ')', ':', '(']
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# ['Good', 'muffins', 'cost', '$', '3.88', 'in', 'New', 'York', '.', 'Please', 'buy', 'me', '...', 'two', 'of', 'them', '.', 'Thanks', '.']
#
#
# "An example with direct speech?" - said a developer
# ['``', 'An', 'example', 'with', 'direct', 'speech', '?', "''", '-', 'said', 'a', 'developer']
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# ['Another', 'example', ':', '``', 'Direct', 'speech', ',', 'the', 'dot', 'before', 'the', 'quote', '.', "''", 'And', 'next', 'sentence', '.']
#
#
# Third example: "The dot after the quote". And next sentence.
# ['Third', 'example', ':', '``', 'The', 'dot', 'after', 'the', 'quote', "''", '.', 'And', 'next', 'sentence', '.']

# %% [markdown]
# #### NLTK: работа со скобочными выражениями
# [ссылка](https://www.nltk.org/api/nltk.tokenize.html#module-nltk.tokenize.sexpr)

# %%
right_parentheses = '(a b (c d)) e f (g)'

# %%
SExprTokenizer().tokenize(right_parentheses)
# Out:
# ['(a b (c d))', 'e', 'f', '(g)']

# %%
wrong_parentheses = 'c) d) e (f (g'

# %%
try:
    SExprTokenizer().tokenize(wrong_parentheses)
except ValueError as error:
    print(error)
# Out:
# Un-matched close paren at char 1

# %% [markdown]
# # spaCy

# %% [markdown]
# Установка: https://spacy.io/usage

# %% [markdown]
# * Токенизация: https://spacy.io/usage/linguistic-features#tokenization
# * Сегментация: https://spacy.io/usage/linguistic-features#sbd

# %% [markdown]
# ### spaCy: сегментация на предложения

# %% [markdown]
# Сегментация в spaCy имеет 4 варианта:
# 1. `Dependency parser` – статистический синтаксический парсер, осуществляющий полный разбор текста, в том числе сегентацию на предложения.
# 1. `Statistical sentence segmenter` – быстрый статистический компонент, осуществляющий только выделение границ предложений.
# 1. `Rule-based pipeline component` – компонент для выделения границ предложений на основе правил.
# 1. `Custom function` – компонент для разработки своей функции сегментации.

# %%
import spacy

# %%
def output_sentences(texts, nlp):
    for text in texts:
        doc = nlp(text)
        print(text)
        for i, sent in enumerate(doc.sents):
            print(f'\t{i}: {sent.text}')
        print('\n')

# %% [markdown]
# #### Вариант 1. Dependency parser

# %%
nlp = spacy.load("en_core_web_sm")

# %%
output_sentences(texts, nlp)
# Out:
# This is very simple sentence.
# 	0: This is very simple sentence.
#
#
# This sentence, has comma!
# 	0: This sentence, has comma!
#
#
# The first sentence. The second sentence.
# 	0: The first sentence.
# 	1: The second sentence.
#
#
# The first sentence.The second sentence without space.
# 	0: The first sentence.
# 	1: The second sentence without space.
#
#
# This sentence does not have a point at the end
# 	0: This sentence does not have a point at the end
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# 	0: This sentence doesn't have an apostrophe...
# 	1: wait...
# 	2: It has word's apostrophe and double  space.
#
#
# An example with "quotes"
# 	0: An example with "quotes"
#
#
# An example with references [1], [2, 3], and this[4]
# 	0: An example with references [1], [2, 3], and this[4]
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# 	0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# 	0: this is an example of the names with lower letters: j. smith, j.smith, j.k.
# 	1: smith, j. k. smith, sohn k. smith, john k.smith, mr.
# 	2: smith, mr.smith
#
#
# An example with
#  newline
# 	0: An example with
#  newline
#
#
# An example with dots... Between sentences...
# 	0: An example with dots... Between sentences...
#
#
# Another example with dots...without space... or with.
# 	0: Another example with dots...without space... or with.
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# 	0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# 	0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# 	0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# 	0: @remy:
# 	1: This is waaaaayyyy too much for you!!!!!!
# 	2: :))) :(
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# 	0: Good muffins cost $3.88
# in New York.
# 	1:
# 	2: Please buy me... two of them.
# 	3:
#
#
# 	4: Thanks.
#
#
# "An example with direct speech?" - said a developer
# 	0: "An example with direct speech?" - said a developer
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# 	0: Another example: "Direct speech, the dot before the quote."
# 	1: And next sentence.
#
#
# Third example: "The dot after the quote". And next sentence.
# 	0: Third example: "The dot after the quote".
# 	1: And next sentence.

# %% [markdown]
# #### Вариант 2. Statistical sentence segmenter

# %%
nlp = spacy.load("en_core_web_sm", exclude=["parser"])
nlp.enable_pipe("senter")

# %%
output_sentences(texts, nlp)
# Out:
# This is very simple sentence.
# 	0: This is very simple sentence.
#
#
# This sentence, has comma!
# 	0: This sentence, has comma!
#
#
# The first sentence. The second sentence.
# 	0: The first sentence.
# 	1: The second sentence.
#
#
# The first sentence.The second sentence without space.
# 	0: The first sentence.
# 	1: The second sentence without space.
#
#
# This sentence does not have a point at the end
# 	0: This sentence does not have a point at the end
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# 	0: This sentence doesn't have an apostrophe... wait...
# 	1: It has word's apostrophe and double  space.
#
#
# An example with "quotes"
# 	0: An example with "quotes"
#
#
# An example with references [1], [2, 3], and this[4]
# 	0: An example with references [1], [2, 3], and this[4]
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# 	0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# 	0: this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j.
# 	1: k. smith, sohn k. smith, john k.smith, mr.
# 	2: smith, mr.smith
#
#
# An example with
#  newline
# 	0: An example with
#  newline
#
#
# An example with dots... Between sentences...
# 	0: An example with dots...
# 	1: Between sentences...
#
#
# Another example with dots...without space... or with.
# 	0: Another example with dots...without space... or with.
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# 	0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# 	0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# 	0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# 	0: @remy: This is waaaaayyyy too much for you!!!!!!
# 	1: :))) :(
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# 	0: Good muffins cost $3.88
# in New York.
# 	1:  Please buy me... two of them.
# 	2:
#
# Thanks.
#
#
# "An example with direct speech?" - said a developer
# 	0: "An example with direct speech?" - said a developer
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# 	0: Another example: "Direct speech, the dot before the quote."
# 	1: And next sentence.
#
#
# Third example: "The dot after the quote". And next sentence.
# 	0: Third example: "The dot after the quote".
# 	1: And next sentence.

# %% [markdown]
# #### Вариант 3. Rule-based pipeline component

# %%
nlp = spacy.load("en_core_web_sm", exclude=["parser"])
nlp.add_pipe("sentencizer")

# %%
# Компоненты в конвейере spaCy
nlp.component_names
# Out:
# ['tok2vec',
#  'tagger',
#  'senter',
#  'ner',
#  'attribute_ruler',
#  'lemmatizer',
#  'sentencizer']

# %%
output_sentences(texts, nlp)
# Out:
# This is very simple sentence.
# 	0: This is very simple sentence.
#
#
# This sentence, has comma!
# 	0: This sentence, has comma!
#
#
# The first sentence. The second sentence.
# 	0: The first sentence.
# 	1: The second sentence.
#
#
# The first sentence.The second sentence without space.
# 	0: The first sentence.
# 	1: The second sentence without space.
#
#
# This sentence does not have a point at the end
# 	0: This sentence does not have a point at the end
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# 	0: This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
#
#
# An example with "quotes"
# 	0: An example with "quotes"
#
#
# An example with references [1], [2, 3], and this[4]
# 	0: An example with references [1], [2, 3], and this[4]
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# 	0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# 	0: this is an example of the names with lower letters: j. smith, j.smith, j.k.
# 	1: smith, j. k. smith, sohn k. smith, john k.smith, mr.
# 	2: smith, mr.smith
#
#
# An example with
#  newline
# 	0: An example with
#  newline
#
#
# An example with dots... Between sentences...
# 	0: An example with dots... Between sentences...
#
#
# Another example with dots...without space... or with.
# 	0: Another example with dots...without space... or with.
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# 	0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# 	0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# 	0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# 	0: @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# 	0: Good muffins cost $3.88
# in New York.
# 	1:  Please buy me... two of them.
# 	2:
#
# Thanks.
#
#
# "An example with direct speech?" - said a developer
# 	0: "An example with direct speech?" -
# 	1: said a developer
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# 	0: Another example: "Direct speech, the dot before the quote."
# 	1: And next sentence.
#
#
# Third example: "The dot after the quote". And next sentence.
# 	0: Third example: "The dot after the quote".
# 	1: And next sentence.

# %% [markdown]
# #### Вариант 4. Custom rule-based strategy
# См. по [ссылке](https://spacy.io/usage/linguistic-features#sbd-custom)

# %% [markdown]
# ### spaCy: токенизация

# %%
nlp = spacy.load("en_core_web_sm")

# %%
for text in texts:
    doc = nlp(text)
    print(text)
    tokens = [str(token) for token in doc]
    print(tokens)
    print('\n')
# Out:
# This is very simple sentence.
# ['This', 'is', 'very', 'simple', 'sentence', '.']
#
#
# This sentence, has comma!
# ['This', 'sentence', ',', 'has', 'comma', '!']
#
#
# The first sentence. The second sentence.
# ['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', '.']
#
#
# The first sentence.The second sentence without space.
# ['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', 'without', 'space', '.']
#
#
# This sentence does not have a point at the end
# ['This', 'sentence', 'does', 'not', 'have', 'a', 'point', 'at', 'the', 'end']
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# ['This', 'sentence', 'does', "n't", 'have', 'an', 'apostrophe', '...', 'wait', '...', 'It', 'has', 'word', "'s", 'apostrophe', 'and', 'double', ' ', 'space', '.']
#
#
# An example with "quotes"
# ['An', 'example', 'with', '"', 'quotes', '"']
#
#
# An example with references [1], [2, 3], and this[4]
# ['An', 'example', 'with', 'references', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'and', 'this[4', ']']
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# ['This', 'is', 'an', 'example', 'of', 'the', 'names', ':', 'J.', 'Smith', ',', 'J.Smith', ',', 'J.K.', 'Smith', ',', 'J.', 'K.', 'Smith', ',', 'John', 'K.', 'Smith', ',', 'John', 'K.Smith', ',', 'Mr.', 'Smith', ',', 'Mr.', 'Smith']
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# ['this', 'is', 'an', 'example', 'of', 'the', 'names', 'with', 'lower', 'letters', ':', 'j.', 'smith', ',', 'j.smith', ',', 'j.k', '.', 'smith', ',', 'j.', 'k.', 'smith', ',', 'sohn', 'k.', 'smith', ',', 'john', 'k.smith', ',', 'mr', '.', 'smith', ',', 'mr.smith']
#
#
# An example with
#  newline
# ['An', 'example', 'with', '\n ', 'newline']
#
#
# An example with dots... Between sentences...
# ['An', 'example', 'with', 'dots', '...', 'Between', 'sentences', '...']
#
#
# Another example with dots...without space... or with.
# ['Another', 'example', 'with', 'dots', '...', 'without', 'space', '...', 'or', 'with', '.']
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# ['An', 'example', 'with', 'hyphen', '-', 'based', 'word', ',', 'for', 'example', ',', 'Emilia', '-', 'Romagna', '.']
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# ['Hyphen', '(', 'or', 'minus', ')', 'on', 'the', '-left', 'and', 'on', 'the', 'right-', 'sides', '.']
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# ['Numbers', 'in', 'various', 'forms', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# ['@remy', ':', 'This', 'is', 'waaaaayyyy', 'too', 'much', 'for', 'you', '!', '!', '!', '!', '!', '!', ':)))', ':(']
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# ['Good', 'muffins', 'cost', '$', '3.88', '\n', 'in', 'New', 'York', '.', ' ', 'Please', 'buy', 'me', '...', 'two', 'of', 'them', '.', '\n\n', 'Thanks', '.']
#
#
# "An example with direct speech?" - said a developer
# ['"', 'An', 'example', 'with', 'direct', 'speech', '?', '"', '-', 'said', 'a', 'developer']
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# ['Another', 'example', ':', '"', 'Direct', 'speech', ',', 'the', 'dot', 'before', 'the', 'quote', '.', '"', 'And', 'next', 'sentence', '.']
#
#
# Third example: "The dot after the quote". And next sentence.
# ['Third', 'example', ':', '"', 'The', 'dot', 'after', 'the', 'quote', '"', '.', 'And', 'next', 'sentence', '.']

# %% [markdown]
# ---
# Предположим, мы хотим, чтобы `Emilia-Romagna` не разделялась на отдельные токены. Для этого создадим свой токенизатор на базе существующего ([ссылка 1](https://spacy.io/usage/linguistic-features#native-tokenizers), [ссылка 2](https://stackoverflow.com/questions/51012476/spacy-custom-tokenizer-to-include-only-hyphen-words-as-tokens-using-infix-regex)):

# %%
import re
from spacy.tokenizer import Tokenizer
from spacy.util import compile_prefix_regex, compile_infix_regex, compile_suffix_regex

def custom_tokenizer(nlp):
    infix_re = re.compile(r'''[—~]''')
    prefix_re = compile_prefix_regex(nlp.Defaults.prefixes)
    suffix_re = compile_suffix_regex(nlp.Defaults.suffixes)

    return Tokenizer(nlp.vocab, prefix_search=prefix_re.search,
                                suffix_search=suffix_re.search,
                                infix_finditer=infix_re.finditer,
                                token_match=None)

# %%
nlp = spacy.load("en_core_web_sm")

nlp.tokenizer = custom_tokenizer(nlp)

# %%
text = 'An example with hyphen-based word, for example, Emilia-Romagna.'
doc = nlp(text)
print(text)
tokens = [str(token) for token in doc]
print(tokens)
# Out:
# An example with hyphen-based word, for example, Emilia-Romagna.
# ['An', 'example', 'with', 'hyphen-based', 'word', ',', 'for', 'example', ',', 'Emilia-Romagna', '.']

# %% [markdown]
# # Stanza

# %% [markdown]
# Токенизация и сегментация в Stanza осуществляется при помощи единого компонента `TokenizeProcessor`.

# %%
import stanza

# %%
# Загрузка англоязычных моделей
stanza.download("en")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 11.4MB/s]
# 2021-05-17 21:52:18 INFO: Downloading default packages for language: en (English)...
# 2021-05-17 21:52:19 INFO: File exists: C:\Users\Евгений\stanza_resources\en\default.zip.
# 2021-05-17 21:52:22 INFO: Finished downloading models and saved to C:\Users\Евгений\stanza_resources.

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize')
# Out:
# 2021-05-17 21:52:22 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2021-05-17 21:52:22 INFO: Use device: gpu
# 2021-05-17 21:52:22 INFO: Loading: tokenize
# 2021-05-17 21:52:24 INFO: Done loading processors!

# %% [markdown]
# ### Stanza: сегментация

# %%
for text in texts:
    doc = nlp(text)
    print(text)
    for i, sent in enumerate(doc.sentences):
        print(f'\t{i}: {sent.text}')
    print('\n')
# Out:
# This is very simple sentence.
# 	0: This is very simple sentence.
#
#
# This sentence, has comma!
# 	0: This sentence, has comma!
#
#
# The first sentence. The second sentence.
# 	0: The first sentence.
# 	1: The second sentence.
#
#
# The first sentence.The second sentence without space.
# 	0: The first sentence.
# 	1: The second sentence without space.
#
#
# This sentence does not have a point at the end
# 	0: This sentence does not have a point at the end
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# 	0: This sentence doesn't have an apostrophe... wait...
# 	1: It has word's apostrophe and double  space.
#
#
# An example with "quotes"
# 	0: An example with "quotes"
#
#
# An example with references [1], [2, 3], and this[4]
# 	0: An example with references [1], [2, 3], and this[4]
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# 	0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# 	0: this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
#
#
# An example with
#  newline
# 	0: An example with
#  newline
#
#
# An example with dots... Between sentences...
# 	0: An example with dots...
# 	1: Between sentences...
#
#
# Another example with dots...without space... or with.
# 	0: Another example with dots...without space... or with.
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# 	0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# 	0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# 	0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# 	0: @remy:
# 	1: This is waaaaayyyy too much for you!!!!!! :))) :(
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# 	0: Good muffins cost $3.88
# in New York.
# 	1: Please buy me... two of them.
# 	2: Thanks.
#
#
# "An example with direct speech?" - said a developer
# 	0: "An example with direct speech?" - said a developer
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# 	0: Another example: "Direct speech, the dot before the quote."
# 	1: And next sentence.
#
#
# Third example: "The dot after the quote". And next sentence.
# 	0: Third example: "The dot after the quote".
# 	1: And next sentence.

# %% [markdown]
# ### Stanza: токенизация

# %%
for text in texts:
    doc = nlp(text)
    print(text)
    tokens = []
    for sentence in doc.sentences:
        tokens += [token.text for token in sentence.tokens]
    print(tokens)
    print('\n')
# Out:
# This is very simple sentence.
# ['This', 'is', 'very', 'simple', 'sentence', '.']
#
#
# This sentence, has comma!
# ['This', 'sentence', ',', 'has', 'comma', '!']
#
#
# The first sentence. The second sentence.
# ['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', '.']
#
#
# The first sentence.The second sentence without space.
# ['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', 'without', 'space', '.']
#
#
# This sentence does not have a point at the end
# ['This', 'sentence', 'does', 'not', 'have', 'a', 'point', 'at', 'the', 'end']
#
#
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
# ['This', 'sentence', 'does', "n't", 'have', 'an', 'apostrophe', '...', 'wait', '...', 'It', 'has', 'word', "'s", 'apostrophe', 'and', 'double', 'space', '.']
#
#
# An example with "quotes"
# ['An', 'example', 'with', '"', 'quotes', '"']
#
#
# An example with references [1], [2, 3], and this[4]
# ['An', 'example', 'with', 'references', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'and', 'this', '[', '4', ']']
#
#
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
# ['This', 'is', 'an', 'example', 'of', 'the', 'names', ':', 'J.', 'Smith', ',', 'J.Smith', ',', 'J.K.', 'Smith', ',', 'J.', 'K.', 'Smith', ',', 'John', 'K.', 'Smith', ',', 'John', 'K.Smith', ',', 'Mr.', 'Smith', ',', 'Mr.Smith']
#
#
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
# ['this', 'is', 'an', 'example', 'of', 'the', 'names', 'with', 'lower', 'letters', ':', 'j.', 'smith', ',', 'j.smith', ',', 'j.k.', 'smith', ',', 'j.', 'k.', 'smith', ',', 'sohn', 'k.', 'smith', ',', 'john', 'k.smith', ',', 'mr.', 'smith', ',', 'mr.smith']
#
#
# An example with
#  newline
# ['An', 'example', 'with', 'newline']
#
#
# An example with dots... Between sentences...
# ['An', 'example', 'with', 'dots', '...', 'Between', 'sentences', '...']
#
#
# Another example with dots...without space... or with.
# ['Another', 'example', 'with', 'dots', '...', 'without', 'space', '...', 'or', 'with', '.']
#
#
# An example with hyphen-based word, for example, Emilia-Romagna.
# ['An', 'example', 'with', 'hyphen', '-', 'based', 'word', ',', 'for', 'example', ',', 'Emilia-Romagna', '.']
#
#
# Hyphen (or minus) on the -left and on the right- sides.
# ['Hyphen', '(', 'or', 'minus', ')', 'on', 'the', '-', 'left', 'and', 'on', 'the', 'right', '-', 'sides', '.']
#
#
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
# ['Numbers', 'in', 'various', 'forms', ':', '1', ',', '2.0', ',', '3', ',', '5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
# ['@remy', ':', 'This', 'is', 'waaaaayyyy', 'too', 'much', 'for', 'you', '!!!!!!', ':)', ')', ')', ':(']
#
#
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
# ['Good', 'muffins', 'cost', '$', '3.88', 'in', 'New', 'York', '.', 'Please', 'buy', 'me', '...', 'two', 'of', 'them', '.', 'Thanks', '.']
#
#
# "An example with direct speech?" - said a developer
# ['"', 'An', 'example', 'with', 'direct', 'speech', '?', '"', '-', 'said', 'a', 'developer']
#
#
# Another example: "Direct speech, the dot before the quote." And next sentence.
# ['Another', 'example', ':', '"', 'Direct', 'speech', ',', 'the', 'dot', 'before', 'the', 'quote', '.', '"', 'And', 'next', 'sentence', '.']
#
#
# Third example: "The dot after the quote". And next sentence.
# ['Third', 'example', ':', '"', 'The', 'dot', 'after', 'the', 'quote', '"', '.', 'And', 'next', 'sentence', '.']

# %% [markdown]
# # Сравнение

# %%
# spaCy - Dependency parser
nlp_spacy1 = spacy.load("en_core_web_sm")

# spaCy - Statistical sentence segmenter
nlp_spacy2 = spacy.load("en_core_web_sm", exclude=["parser"])
nlp_spacy2.enable_pipe("senter")

# spaCy - Rule-based pipeline component
nlp_spacy3 = spacy.load("en_core_web_sm", exclude=["parser"])
nlp_spacy3.add_pipe("sentencizer")

# stanza
nlp_stanza = stanza.Pipeline(lang='en', processors='tokenize')
# Out:
# 2021-05-17 21:52:26 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2021-05-17 21:52:26 INFO: Use device: gpu
# 2021-05-17 21:52:26 INFO: Loading: tokenize
# 2021-05-17 21:52:26 INFO: Done loading processors!

# %% [markdown]
# ### Сегментация

# %%
for text in texts:
    
    print(f'{text}\n')
    
    # nltk
    print('\tnltk:')
    sentences_nltk = sent_tokenize(text)
    for i, sentence in enumerate(sentences_nltk):
        print(f'\t\t{i}: {sentence}')
    print('\n')
    
    # spaCy - Dependency parser
    print('\tspaCy1:')
    doc_spacy1 = nlp_spacy1(text)
    for i, sent in enumerate(doc_spacy1.sents):
        print(f'\t\t{i}: {sent.text}')
    print('\n')
    
    # spaCy - Statistical sentence segmenter
    print('\tspaCy2:')
    doc_spacy2 = nlp_spacy2(text)
    for i, sent in enumerate(doc_spacy2.sents):
        print(f'\t\t{i}: {sent.text}')
    print('\n')    

    # spaCy - Rule-based pipeline component
    print('\tspaCy3:')
    doc_spacy3 = nlp_spacy3(text)
    for i, sent in enumerate(doc_spacy3.sents):
        print(f'\t\t{i}: {sent.text}')
    print('\n')    
    
    # stanza
    print('\tstanza:')
    doc_stanza = nlp_stanza(text)
    for i, sent in enumerate(doc_stanza.sentences):
        print(f'\t\t{i}: {sent.text}')
    print('\n')
    
    print('-----------------------------------------------------------------------')
# Out:
# This is very simple sentence.
#
# 	nltk:
# 		0: This is very simple sentence.
#
#
# 	spaCy1:
# 		0: This is very simple sentence.
#
#
# 	spaCy2:
# 		0: This is very simple sentence.
#
#
# 	spaCy3:
# 		0: This is very simple sentence.
#
#
# 	stanza:
# 		0: This is very simple sentence.
#
#
# -----------------------------------------------------------------------
# This sentence, has comma!
#
# 	nltk:
# 		0: This sentence, has comma!
#
#
# 	spaCy1:
# 		0: This sentence, has comma!
#
#
# 	spaCy2:
# 		0: This sentence, has comma!
#
#
# 	spaCy3:
# 		0: This sentence, has comma!
#
#
# 	stanza:
# 		0: This sentence, has comma!
#
#
# -----------------------------------------------------------------------
# The first sentence. The second sentence.
#
# 	nltk:
# 		0: The first sentence.
# 		1: The second sentence.
#
#
# 	spaCy1:
# 		0: The first sentence.
# 		1: The second sentence.
#
#
# 	spaCy2:
# 		0: The first sentence.
# 		1: The second sentence.
#
#
# 	spaCy3:
# 		0: The first sentence.
# 		1: The second sentence.
#
#
# 	stanza:
# 		0: The first sentence.
# 		1: The second sentence.
#
#
# -----------------------------------------------------------------------
# The first sentence.The second sentence without space.
#
# 	nltk:
# 		0: The first sentence.The second sentence without space.
#
#
# 	spaCy1:
# 		0: The first sentence.
# 		1: The second sentence without space.
#
#
# 	spaCy2:
# 		0: The first sentence.
# 		1: The second sentence without space.
#
#
# 	spaCy3:
# 		0: The first sentence.
# 		1: The second sentence without space.
#
#
# 	stanza:
# 		0: The first sentence.
# 		1: The second sentence without space.
#
#
# -----------------------------------------------------------------------
# This sentence does not have a point at the end
#
# 	nltk:
# 		0: This sentence does not have a point at the end
#
#
# 	spaCy1:
# 		0: This sentence does not have a point at the end
#
#
# 	spaCy2:
# 		0: This sentence does not have a point at the end
#
#
# 	spaCy3:
# 		0: This sentence does not have a point at the end
#
#
# 	stanza:
# 		0: This sentence does not have a point at the end
#
#
# -----------------------------------------------------------------------
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
#
# 	nltk:
# 		0: This sentence doesn't have an apostrophe... wait...
# 		1: It has word's apostrophe and double  space.
#
#
# 	spaCy1:
# 		0: This sentence doesn't have an apostrophe...
# 		1: wait...
# 		2: It has word's apostrophe and double  space.
#
#
# 	spaCy2:
# 		0: This sentence doesn't have an apostrophe... wait...
# 		1: It has word's apostrophe and double  space.
#
#
# 	spaCy3:
# 		0: This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
#
#
# 	stanza:
# 		0: This sentence doesn't have an apostrophe... wait...
# 		1: It has word's apostrophe and double  space.
#
#
# -----------------------------------------------------------------------
# An example with "quotes"
#
# 	nltk:
# 		0: An example with "quotes"
#
#
# 	spaCy1:
# 		0: An example with "quotes"
#
#
# 	spaCy2:
# 		0: An example with "quotes"
#
#
# 	spaCy3:
# 		0: An example with "quotes"
#
#
# 	stanza:
# 		0: An example with "quotes"
#
#
# -----------------------------------------------------------------------
# An example with references [1], [2, 3], and this[4]
#
# 	nltk:
# 		0: An example with references [1], [2, 3], and this[4]
#
#
# 	spaCy1:
# 		0: An example with references [1], [2, 3], and this[4]
#
#
# 	spaCy2:
# 		0: An example with references [1], [2, 3], and this[4]
#
#
# 	spaCy3:
# 		0: An example with references [1], [2, 3], and this[4]
#
#
# 	stanza:
# 		0: An example with references [1], [2, 3], and this[4]
#
#
# -----------------------------------------------------------------------
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
# 	nltk:
# 		0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# 	spaCy1:
# 		0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# 	spaCy2:
# 		0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# 	spaCy3:
# 		0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# 	stanza:
# 		0: This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
#
# -----------------------------------------------------------------------
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
#
# 	nltk:
# 		0: this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
#
#
# 	spaCy1:
# 		0: this is an example of the names with lower letters: j. smith, j.smith, j.k.
# 		1: smith, j. k. smith, sohn k. smith, john k.smith, mr.
# 		2: smith, mr.smith
#
#
# 	spaCy2:
# 		0: this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j.
# 		1: k. smith, sohn k. smith, john k.smith, mr.
# 		2: smith, mr.smith
#
#
# 	spaCy3:
# 		0: this is an example of the names with lower letters: j. smith, j.smith, j.k.
# 		1: smith, j. k. smith, sohn k. smith, john k.smith, mr.
# 		2: smith, mr.smith
#
#
# 	stanza:
# 		0: this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
#
#
# -----------------------------------------------------------------------
# An example with
#  newline
#
# 	nltk:
# 		0: An example with
#  newline
#
#
# 	spaCy1:
# 		0: An example with
#  newline
#
#
# 	spaCy2:
# 		0: An example with
#  newline
#
#
# 	spaCy3:
# 		0: An example with
#  newline
#
#
# 	stanza:
# 		0: An example with
#  newline
#
#
# -----------------------------------------------------------------------
# An example with dots... Between sentences...
#
# 	nltk:
# 		0: An example with dots...
# 		1: Between sentences...
#
#
# 	spaCy1:
# 		0: An example with dots... Between sentences...
#
#
# 	spaCy2:
# 		0: An example with dots...
# 		1: Between sentences...
#
#
# 	spaCy3:
# 		0: An example with dots... Between sentences...
#
#
# 	stanza:
# 		0: An example with dots...
# 		1: Between sentences...
#
#
# -----------------------------------------------------------------------
# Another example with dots...without space... or with.
#
# 	nltk:
# 		0: Another example with dots...without space... or with.
#
#
# 	spaCy1:
# 		0: Another example with dots...without space... or with.
#
#
# 	spaCy2:
# 		0: Another example with dots...without space... or with.
#
#
# 	spaCy3:
# 		0: Another example with dots...without space... or with.
#
#
# 	stanza:
# 		0: Another example with dots...without space... or with.
#
#
# -----------------------------------------------------------------------
# An example with hyphen-based word, for example, Emilia-Romagna.
#
# 	nltk:
# 		0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# 	spaCy1:
# 		0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# 	spaCy2:
# 		0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# 	spaCy3:
# 		0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# 	stanza:
# 		0: An example with hyphen-based word, for example, Emilia-Romagna.
#
#
# -----------------------------------------------------------------------
# Hyphen (or minus) on the -left and on the right- sides.
#
# 	nltk:
# 		0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# 	spaCy1:
# 		0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# 	spaCy2:
# 		0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# 	spaCy3:
# 		0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# 	stanza:
# 		0: Hyphen (or minus) on the -left and on the right- sides.
#
#
# -----------------------------------------------------------------------
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
# 	nltk:
# 		0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	spaCy1:
# 		0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	spaCy2:
# 		0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	spaCy3:
# 		0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	stanza:
# 		0: Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# -----------------------------------------------------------------------
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
#
# 	nltk:
# 		0: @remy: This is waaaaayyyy too much for you!!!!!!
# 		1: :))) :(
#
#
# 	spaCy1:
# 		0: @remy:
# 		1: This is waaaaayyyy too much for you!!!!!!
# 		2: :))) :(
#
#
# 	spaCy2:
# 		0: @remy: This is waaaaayyyy too much for you!!!!!!
# 		1: :))) :(
#
#
# 	spaCy3:
# 		0: @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
#
#
# 	stanza:
# 		0: @remy:
# 		1: This is waaaaayyyy too much for you!!!!!! :))) :(
#
#
# -----------------------------------------------------------------------
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
#
# 	nltk:
# 		0: Good muffins cost $3.88
# in New York.
# 		1: Please buy me... two of them.
# 		2: Thanks.
#
#
# 	spaCy1:
# 		0: Good muffins cost $3.88
# in New York.
# 		1:
# 		2: Please buy me... two of them.
# 		3:
#
#
# 		4: Thanks.
#
#
# 	spaCy2:
# 		0: Good muffins cost $3.88
# in New York.
# 		1:  Please buy me... two of them.
# 		2:
#
# Thanks.
#
#
# 	spaCy3:
# 		0: Good muffins cost $3.88
# in New York.
# 		1:  Please buy me... two of them.
# 		2:
#
# Thanks.
#
#
# 	stanza:
# 		0: Good muffins cost $3.88
# in New York.
# 		1: Please buy me... two of them.
# 		2: Thanks.
#
#
# -----------------------------------------------------------------------
# "An example with direct speech?" - said a developer
#
# 	nltk:
# 		0: "An example with direct speech?"
# 		1: - said a developer
#
#
# 	spaCy1:
# 		0: "An example with direct speech?" - said a developer
#
#
# 	spaCy2:
# 		0: "An example with direct speech?" - said a developer
#
#
# 	spaCy3:
# 		0: "An example with direct speech?" -
# 		1: said a developer
#
#
# 	stanza:
# 		0: "An example with direct speech?" - said a developer
#
#
# -----------------------------------------------------------------------
# Another example: "Direct speech, the dot before the quote." And next sentence.
#
# 	nltk:
# 		0: Another example: "Direct speech, the dot before the quote."
# 		1: And next sentence.
#
#
# 	spaCy1:
# 		0: Another example: "Direct speech, the dot before the quote."
# 		1: And next sentence.
#
#
# 	spaCy2:
# 		0: Another example: "Direct speech, the dot before the quote."
# 		1: And next sentence.
#
#
# 	spaCy3:
# 		0: Another example: "Direct speech, the dot before the quote."
# 		1: And next sentence.
#
#
# 	stanza:
# 		0: Another example: "Direct speech, the dot before the quote."
# 		1: And next sentence.
#
#
# -----------------------------------------------------------------------
# Third example: "The dot after the quote". And next sentence.
#
# 	nltk:
# 		0: Third example: "The dot after the quote".
# 		1: And next sentence.
#
#
# 	spaCy1:
# 		0: Third example: "The dot after the quote".
# 		1: And next sentence.
#
#
# 	spaCy2:
# 		0: Third example: "The dot after the quote".
# 		1: And next sentence.
#
#
# 	spaCy3:
# 		0: Third example: "The dot after the quote".
# 		1: And next sentence.
#
#
# 	stanza:
# 		0: Third example: "The dot after the quote".
# 		1: And next sentence.
#
#
# -----------------------------------------------------------------------

# %% [markdown]
# ### Токенизация

# %%
# spacy
nlp_spacy = spacy.load("en_core_web_sm")

# stanza
nlp_stanza = stanza.Pipeline(lang='en', processors='tokenize')
# Out:
# 2021-05-17 21:52:27 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# ========================
#
# 2021-05-17 21:52:27 INFO: Use device: gpu
# 2021-05-17 21:52:27 INFO: Loading: tokenize
# 2021-05-17 21:52:27 INFO: Done loading processors!

# %%
for text in texts:
    
    print(f'{text}\n')
    
    # nltk
    print('\tnltk:')
    tokens_nltk = word_tokenize(text)
    print(f'\t{tokens_nltk}')
    print('\n')
    
    # spaCy
    print('\tspaCy:')
    doc_spacy = nlp_spacy(text)
    tokens_spacy = [str(token) for token in doc_spacy]
    print(f'\t{tokens_spacy}')
    print('\n')
       
    # stanza
    print('\tstanza:')
    doc_stanza = nlp_stanza(text)
    tokens_stanza = []
    for sentence in doc_stanza.sentences:
        tokens_stanza += [token.text for token in sentence.tokens]
    print(f'\t{tokens_stanza}')
    print('\n')
    
    print('-----------------------------------------------------------------------')
# Out:
# This is very simple sentence.
#
# 	nltk:
# 	['This', 'is', 'very', 'simple', 'sentence', '.']
#
#
# 	spaCy:
# 	['This', 'is', 'very', 'simple', 'sentence', '.']
#
#
# 	stanza:
# 	['This', 'is', 'very', 'simple', 'sentence', '.']
#
#
# -----------------------------------------------------------------------
# This sentence, has comma!
#
# 	nltk:
# 	['This', 'sentence', ',', 'has', 'comma', '!']
#
#
# 	spaCy:
# 	['This', 'sentence', ',', 'has', 'comma', '!']
#
#
# 	stanza:
# 	['This', 'sentence', ',', 'has', 'comma', '!']
#
#
# -----------------------------------------------------------------------
# The first sentence. The second sentence.
#
# 	nltk:
# 	['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', '.']
#
#
# 	spaCy:
# 	['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', '.']
#
#
# 	stanza:
# 	['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', '.']
#
#
# -----------------------------------------------------------------------
# The first sentence.The second sentence without space.
#
# 	nltk:
# 	['The', 'first', 'sentence.The', 'second', 'sentence', 'without', 'space', '.']
#
#
# 	spaCy:
# 	['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', 'without', 'space', '.']
#
#
# 	stanza:
# 	['The', 'first', 'sentence', '.', 'The', 'second', 'sentence', 'without', 'space', '.']
#
#
# -----------------------------------------------------------------------
# This sentence does not have a point at the end
#
# 	nltk:
# 	['This', 'sentence', 'does', 'not', 'have', 'a', 'point', 'at', 'the', 'end']
#
#
# 	spaCy:
# 	['This', 'sentence', 'does', 'not', 'have', 'a', 'point', 'at', 'the', 'end']
#
#
# 	stanza:
# 	['This', 'sentence', 'does', 'not', 'have', 'a', 'point', 'at', 'the', 'end']
#
#
# -----------------------------------------------------------------------
# This sentence doesn't have an apostrophe... wait... It has word's apostrophe and double  space.
#
# 	nltk:
# 	['This', 'sentence', 'does', "n't", 'have', 'an', 'apostrophe', '...', 'wait', '...', 'It', 'has', 'word', "'s", 'apostrophe', 'and', 'double', 'space', '.']
#
#
# 	spaCy:
# 	['This', 'sentence', 'does', "n't", 'have', 'an', 'apostrophe', '...', 'wait', '...', 'It', 'has', 'word', "'s", 'apostrophe', 'and', 'double', ' ', 'space', '.']
#
#
# 	stanza:
# 	['This', 'sentence', 'does', "n't", 'have', 'an', 'apostrophe', '...', 'wait', '...', 'It', 'has', 'word', "'s", 'apostrophe', 'and', 'double', 'space', '.']
#
#
# -----------------------------------------------------------------------
# An example with "quotes"
#
# 	nltk:
# 	['An', 'example', 'with', '``', 'quotes', "''"]
#
#
# 	spaCy:
# 	['An', 'example', 'with', '"', 'quotes', '"']
#
#
# 	stanza:
# 	['An', 'example', 'with', '"', 'quotes', '"']
#
#
# -----------------------------------------------------------------------
# An example with references [1], [2, 3], and this[4]
#
# 	nltk:
# 	['An', 'example', 'with', 'references', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'and', 'this', '[', '4', ']']
#
#
# 	spaCy:
# 	['An', 'example', 'with', 'references', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'and', 'this[4', ']']
#
#
# 	stanza:
# 	['An', 'example', 'with', 'references', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'and', 'this', '[', '4', ']']
#
#
# -----------------------------------------------------------------------
# This is an example of the names: J. Smith, J.Smith, J.K. Smith, J. K. Smith, John K. Smith, John K.Smith, Mr. Smith, Mr.Smith
#
# 	nltk:
# 	['This', 'is', 'an', 'example', 'of', 'the', 'names', ':', 'J.', 'Smith', ',', 'J.Smith', ',', 'J.K.', 'Smith', ',', 'J.', 'K.', 'Smith', ',', 'John', 'K.', 'Smith', ',', 'John', 'K.Smith', ',', 'Mr.', 'Smith', ',', 'Mr.Smith']
#
#
# 	spaCy:
# 	['This', 'is', 'an', 'example', 'of', 'the', 'names', ':', 'J.', 'Smith', ',', 'J.Smith', ',', 'J.K.', 'Smith', ',', 'J.', 'K.', 'Smith', ',', 'John', 'K.', 'Smith', ',', 'John', 'K.Smith', ',', 'Mr.', 'Smith', ',', 'Mr.', 'Smith']
#
#
# 	stanza:
# 	['This', 'is', 'an', 'example', 'of', 'the', 'names', ':', 'J.', 'Smith', ',', 'J.Smith', ',', 'J.K.', 'Smith', ',', 'J.', 'K.', 'Smith', ',', 'John', 'K.', 'Smith', ',', 'John', 'K.Smith', ',', 'Mr.', 'Smith', ',', 'Mr.Smith']
#
#
# -----------------------------------------------------------------------
# this is an example of the names with lower letters: j. smith, j.smith, j.k. smith, j. k. smith, sohn k. smith, john k.smith, mr. smith, mr.smith
#
# 	nltk:
# 	['this', 'is', 'an', 'example', 'of', 'the', 'names', 'with', 'lower', 'letters', ':', 'j.', 'smith', ',', 'j.smith', ',', 'j.k.', 'smith', ',', 'j.', 'k.', 'smith', ',', 'sohn', 'k.', 'smith', ',', 'john', 'k.smith', ',', 'mr.', 'smith', ',', 'mr.smith']
#
#
# 	spaCy:
# 	['this', 'is', 'an', 'example', 'of', 'the', 'names', 'with', 'lower', 'letters', ':', 'j.', 'smith', ',', 'j.smith', ',', 'j.k', '.', 'smith', ',', 'j.', 'k.', 'smith', ',', 'sohn', 'k.', 'smith', ',', 'john', 'k.smith', ',', 'mr', '.', 'smith', ',', 'mr.smith']
#
#
# 	stanza:
# 	['this', 'is', 'an', 'example', 'of', 'the', 'names', 'with', 'lower', 'letters', ':', 'j.', 'smith', ',', 'j.smith', ',', 'j.k.', 'smith', ',', 'j.', 'k.', 'smith', ',', 'sohn', 'k.', 'smith', ',', 'john', 'k.smith', ',', 'mr.', 'smith', ',', 'mr.smith']
#
#
# -----------------------------------------------------------------------
# An example with
#  newline
#
# 	nltk:
# 	['An', 'example', 'with', 'newline']
#
#
# 	spaCy:
# 	['An', 'example', 'with', '\n ', 'newline']
#
#
# 	stanza:
# 	['An', 'example', 'with', 'newline']
#
#
# -----------------------------------------------------------------------
# An example with dots... Between sentences...
#
# 	nltk:
# 	['An', 'example', 'with', 'dots', '...', 'Between', 'sentences', '...']
#
#
# 	spaCy:
# 	['An', 'example', 'with', 'dots', '...', 'Between', 'sentences', '...']
#
#
# 	stanza:
# 	['An', 'example', 'with', 'dots', '...', 'Between', 'sentences', '...']
#
#
# -----------------------------------------------------------------------
# Another example with dots...without space... or with.
#
# 	nltk:
# 	['Another', 'example', 'with', 'dots', '...', 'without', 'space', '...', 'or', 'with', '.']
#
#
# 	spaCy:
# 	['Another', 'example', 'with', 'dots', '...', 'without', 'space', '...', 'or', 'with', '.']
#
#
# 	stanza:
# 	['Another', 'example', 'with', 'dots', '...', 'without', 'space', '...', 'or', 'with', '.']
#
#
# -----------------------------------------------------------------------
# An example with hyphen-based word, for example, Emilia-Romagna.
#
# 	nltk:
# 	['An', 'example', 'with', 'hyphen-based', 'word', ',', 'for', 'example', ',', 'Emilia-Romagna', '.']
#
#
# 	spaCy:
# 	['An', 'example', 'with', 'hyphen', '-', 'based', 'word', ',', 'for', 'example', ',', 'Emilia', '-', 'Romagna', '.']
#
#
# 	stanza:
# 	['An', 'example', 'with', 'hyphen', '-', 'based', 'word', ',', 'for', 'example', ',', 'Emilia-Romagna', '.']
#
#
# -----------------------------------------------------------------------
# Hyphen (or minus) on the -left and on the right- sides.
#
# 	nltk:
# 	['Hyphen', '(', 'or', 'minus', ')', 'on', 'the', '-left', 'and', 'on', 'the', 'right-', 'sides', '.']
#
#
# 	spaCy:
# 	['Hyphen', '(', 'or', 'minus', ')', 'on', 'the', '-left', 'and', 'on', 'the', 'right-', 'sides', '.']
#
#
# 	stanza:
# 	['Hyphen', '(', 'or', 'minus', ')', 'on', 'the', '-', 'left', 'and', 'on', 'the', 'right', '-', 'sides', '.']
#
#
# -----------------------------------------------------------------------
# Numbers in various forms: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
# 	nltk:
# 	['Numbers', 'in', 'various', 'forms', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# 	spaCy:
# 	['Numbers', 'in', 'various', 'forms', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# 	stanza:
# 	['Numbers', 'in', 'various', 'forms', ':', '1', ',', '2.0', ',', '3', ',', '5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# -----------------------------------------------------------------------
# @remy: This is waaaaayyyy too much for you!!!!!! :))) :(
#
# 	nltk:
# 	['@', 'remy', ':', 'This', 'is', 'waaaaayyyy', 'too', 'much', 'for', 'you', '!', '!', '!', '!', '!', '!', ':', ')', ')', ')', ':', '(']
#
#
# 	spaCy:
# 	['@remy', ':', 'This', 'is', 'waaaaayyyy', 'too', 'much', 'for', 'you', '!', '!', '!', '!', '!', '!', ':)))', ':(']
#
#
# 	stanza:
# 	['@remy', ':', 'This', 'is', 'waaaaayyyy', 'too', 'much', 'for', 'you', '!!!!!!', ':)', ')', ')', ':(']
#
#
# -----------------------------------------------------------------------
# Good muffins cost $3.88
# in New York.  Please buy me... two of them.
#
# Thanks.
#
# 	nltk:
# 	['Good', 'muffins', 'cost', '$', '3.88', 'in', 'New', 'York', '.', 'Please', 'buy', 'me', '...', 'two', 'of', 'them', '.', 'Thanks', '.']
#
#
# 	spaCy:
# 	['Good', 'muffins', 'cost', '$', '3.88', '\n', 'in', 'New', 'York', '.', ' ', 'Please', 'buy', 'me', '...', 'two', 'of', 'them', '.', '\n\n', 'Thanks', '.']
#
#
# 	stanza:
# 	['Good', 'muffins', 'cost', '$', '3.88', 'in', 'New', 'York', '.', 'Please', 'buy', 'me', '...', 'two', 'of', 'them', '.', 'Thanks', '.']
#
#
# -----------------------------------------------------------------------
# "An example with direct speech?" - said a developer
#
# 	nltk:
# 	['``', 'An', 'example', 'with', 'direct', 'speech', '?', "''", '-', 'said', 'a', 'developer']
#
#
# 	spaCy:
# 	['"', 'An', 'example', 'with', 'direct', 'speech', '?', '"', '-', 'said', 'a', 'developer']
#
#
# 	stanza:
# 	['"', 'An', 'example', 'with', 'direct', 'speech', '?', '"', '-', 'said', 'a', 'developer']
#
#
# -----------------------------------------------------------------------
# Another example: "Direct speech, the dot before the quote." And next sentence.
#
# 	nltk:
# 	['Another', 'example', ':', '``', 'Direct', 'speech', ',', 'the', 'dot', 'before', 'the', 'quote', '.', "''", 'And', 'next', 'sentence', '.']
#
#
# 	spaCy:
# 	['Another', 'example', ':', '"', 'Direct', 'speech', ',', 'the', 'dot', 'before', 'the', 'quote', '.', '"', 'And', 'next', 'sentence', '.']
#
#
# 	stanza:
# 	['Another', 'example', ':', '"', 'Direct', 'speech', ',', 'the', 'dot', 'before', 'the', 'quote', '.', '"', 'And', 'next', 'sentence', '.']
#
#
# -----------------------------------------------------------------------
# Third example: "The dot after the quote". And next sentence.
#
# 	nltk:
# 	['Third', 'example', ':', '``', 'The', 'dot', 'after', 'the', 'quote', "''", '.', 'And', 'next', 'sentence', '.']
#
#
# 	spaCy:
# 	['Third', 'example', ':', '"', 'The', 'dot', 'after', 'the', 'quote', '"', '.', 'And', 'next', 'sentence', '.']
#
#
# 	stanza:
# 	['Third', 'example', ':', '"', 'The', 'dot', 'after', 'the', 'quote', '"', '.', 'And', 'next', 'sentence', '.']
#
#
# -----------------------------------------------------------------------

# %% [markdown]
# # Русский язык

# %%
texts_rus = [
    'Пример простого предложения',
    'Пример простого предложения с точкой.',
    'Тоже пример предложения, но с восклицательным знаком!',
    'Первое предложение. Второе предложение.',
    'Первое предложение.Второе предложение без пробела.',
    'У этого предложения в конце нет точки',
    "В этом предложении есть апостроф' и двойной  пробел.",
    'Пример с "кавычками"',
    'Пример со ссылками [1], [2, 3], и вот так[4]',
    'Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н. Иванов, проф.Иванов',
    'Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов, проф.иванов',
    'Пример с \n переносом',
    'Пример с многоточием... Между предложениями...',
    'Другой пример с многоточием...без пробелов... и с ними.',
    'Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.',
    'Дефисы (или минус) -слева и справа-',
    'Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%', 
    '@john: Это суууупер!!!!!! :))) :(',
    'Классный ресторан :) Обязательно приду ещё раз!',
    'Хороший маффин стоит 3,88 \nв Нью-Йорке. Пожалуйста, купи мне... два.\n\nСпасибо.',
    '"Пример с прямой речью?" - говорит разработчик',
    'Вот ещё один пример: "Тоже прямая речь, точка до кавычек." И следующее предложение.',
    'Третий пример: "Точка после кавычек". И следующее предложение.',
    '10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.',
    'Изъято 20 тыс. шт. патронов.'
]

# %% [markdown]
# ### Natasha
# Проект `Natasha` содержит библиотеки и компоненты для решения базовых задач обработки русского языка: сегментация на токены и предложения, морфологический и синтаксический анализ, извлечение именованных сущностей:
# * [Github](https://natasha.github.io)
# * [Статья на Хабре](https://habr.com/ru/post/516098/)
# * [Инструкция по установке](https://github.com/natasha/natasha#install)
#
# Токенизация и сегментация [реализована](https://github.com/natasha/razdel) в модуле `Razdel`.
# В проекте `Natasha` проводилось сравнение [токенизаторов](https://github.com/natasha/razdel#tokens) и [сегментаторов](https://github.com/natasha/razdel#sentences).

# %%
from razdel import tokenize, sentenize

# %% [markdown]
# ### Русский язык: сегментация

# %% [markdown]
# Добавлена библиотека `ru_sent_tokenize` (только для русского языка): https://pypi.org/project/rusenttokenize/

# %%
from rusenttokenize import ru_sent_tokenize

# %% [markdown]
# Русскоязычные [модели](https://spacy.io/models/ru) в spaCy:
# - ru_core_news_sm (16 MB) – small
# - ru_core_news_md (41 MB) – medium
# - ru_core_news_lg (491 MB) – large
#
# Установка: `python -m spacy download ru_core_news_sm`

# %%
spacy_model_name = 'ru_core_news_sm'
# spacy_model_name = 'ru_core_news_md'
# spacy_model_name = 'ru_core_news_lg'

# %%
# Загрузка русскоязычных моделей Stanza
stanza.download("ru")
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 11.4MB/s]
# 2021-05-17 21:52:27 INFO: Downloading default packages for language: ru (Russian)...
# 2021-05-17 21:52:28 INFO: File exists: C:\Users\Евгений\stanza_resources\ru\default.zip.
# 2021-05-17 21:52:32 INFO: Finished downloading models and saved to C:\Users\Евгений\stanza_resources.

# %%
# spaCy - Dependency parser
nlp_spacy1 = spacy.load(spacy_model_name)

# spaCy - Statistical sentence segmenter
nlp_spacy2 = spacy.load(spacy_model_name, exclude=["parser"])
nlp_spacy2.enable_pipe("senter")

# spaCy - Rule-based pipeline component
nlp_spacy3 = spacy.load(spacy_model_name, exclude=["parser"])
nlp_spacy3.add_pipe("sentencizer")

# %%
# stanza
nlp_stanza = stanza.Pipeline(lang='ru', processors='tokenize')
# Out:
# 2021-05-17 21:52:34 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# =========================
#
# 2021-05-17 21:52:34 INFO: Use device: gpu
# 2021-05-17 21:52:34 INFO: Loading: tokenize
# 2021-05-17 21:52:34 INFO: Done loading processors!

# %%
for text in texts_rus:
    
    print(f'{text}\n')
    
    # nltk
    print('\tnltk:')
    sentences_nltk = sent_tokenize(text, language='russian')
    for i, sentence in enumerate(sentences_nltk):
        print(f'\t\t{i}: {sentence}')
    print('\n')
    
    # spaCy - Dependency parser
    print('\tspaCy1:')
    doc_spacy1 = nlp_spacy1(text)
    for i, sent in enumerate(doc_spacy1.sents):
        print(f'\t\t{i}: {sent.text}')
    print('\n')
    
    # spaCy - Statistical sentence segmenter
    print('\tspaCy2:')
    doc_spacy2 = nlp_spacy2(text)
    for i, sent in enumerate(doc_spacy2.sents):
        print(f'\t\t{i}: {sent.text}')
    print('\n')    

    # spaCy - Rule-based pipeline component
    print('\tspaCy3:')
    doc_spacy3 = nlp_spacy3(text)
    for i, sent in enumerate(doc_spacy3.sents):
        print(f'\t\t{i}: {sent.text}')
    print('\n')    
    
    # stanza
    print('\tstanza:')
    doc_stanza = nlp_stanza(text)
    for i, sent in enumerate(doc_stanza.sentences):
        print(f'\t\t{i}: {sent.text}')
    print('\n')
    
    # Natasha
    print('\tNatasha:')
    for i, sent in enumerate(sentenize(text)):
        print(f'\t\t{i}: {sent.text}')
    print('\n')
    
    # ru_sent_tokenize
    print('\tru_sent_tokenize:')
    sentences_rusenttokenize = ru_sent_tokenize(text)
    for i, sent in enumerate(sentences_rusenttokenize):
        print(f'\t\t{i}: {sent}')
    print('\n')
    
    print('-----------------------------------------------------------------------')
# Out:
# Пример простого предложения
#
# 	nltk:
# 		0: Пример простого предложения
#
#
# 	spaCy1:
# 		0: Пример простого предложения
#
#
# 	spaCy2:
# 		0: Пример простого предложения
#
#
# 	spaCy3:
# 		0: Пример простого предложения
#
#
# 	stanza:
# 		0: Пример простого предложения
#
#
# 	Natasha:
# 		0: Пример простого предложения
#
#
# 	ru_sent_tokenize:
# 		0: Пример простого предложения
#
#
# -----------------------------------------------------------------------
# Пример простого предложения с точкой.
#
# 	nltk:
# 		0: Пример простого предложения с точкой.
#
#
# 	spaCy1:
# 		0: Пример простого предложения с точкой.
#
#
# 	spaCy2:
# 		0: Пример простого предложения с точкой.
#
#
# 	spaCy3:
# 		0: Пример простого предложения с точкой.
#
#
# 	stanza:
# 		0: Пример простого предложения с точкой.
#
#
# 	Natasha:
# 		0: Пример простого предложения с точкой.
#
#
# 	ru_sent_tokenize:
# 		0: Пример простого предложения с точкой.
#
#
# -----------------------------------------------------------------------
# Тоже пример предложения, но с восклицательным знаком!
#
# 	nltk:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# 	spaCy1:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# 	spaCy2:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# 	spaCy3:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# 	stanza:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# 	Natasha:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# 	ru_sent_tokenize:
# 		0: Тоже пример предложения, но с восклицательным знаком!
#
#
# -----------------------------------------------------------------------
# Первое предложение. Второе предложение.
#
# 	nltk:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# 	spaCy1:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# 	spaCy2:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# 	spaCy3:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# 	stanza:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# 	Natasha:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# 	ru_sent_tokenize:
# 		0: Первое предложение.
# 		1: Второе предложение.
#
#
# -----------------------------------------------------------------------
# Первое предложение.Второе предложение без пробела.
#
# 	nltk:
# 		0: Первое предложение.Второе предложение без пробела.
#
#
# 	spaCy1:
# 		0: Первое предложение.
# 		1: Второе предложение без пробела.
#
#
# 	spaCy2:
# 		0: Первое предложение.
# 		1: Второе предложение без пробела.
#
#
# 	spaCy3:
# 		0: Первое предложение.
# 		1: Второе предложение без пробела.
#
#
# 	stanza:
# 		0: Первое предложение.
# 		1: Второе предложение без пробела.
#
#
# 	Natasha:
# 		0: Первое предложение.Второе предложение без пробела.
#
#
# 	ru_sent_tokenize:
# 		0: Первое предложение.Второе предложение без пробела.
#
#
# -----------------------------------------------------------------------
# У этого предложения в конце нет точки
#
# 	nltk:
# 		0: У этого предложения в конце нет точки
#
#
# 	spaCy1:
# 		0: У этого предложения в конце нет
# 		1: точки
#
#
# 	spaCy2:
# 		0: У этого предложения в конце нет точки
#
#
# 	spaCy3:
# 		0: У этого предложения в конце нет точки
#
#
# 	stanza:
# 		0: У этого предложения в конце нет точки
#
#
# 	Natasha:
# 		0: У этого предложения в конце нет точки
#
#
# 	ru_sent_tokenize:
# 		0: У этого предложения в конце нет точки
#
#
# -----------------------------------------------------------------------
# В этом предложении есть апостроф' и двойной  пробел.
#
# 	nltk:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# 	spaCy1:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# 	spaCy2:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# 	spaCy3:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# 	stanza:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# 	Natasha:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# 	ru_sent_tokenize:
# 		0: В этом предложении есть апостроф' и двойной  пробел.
#
#
# -----------------------------------------------------------------------
# Пример с "кавычками"
#
# 	nltk:
# 		0: Пример с "кавычками"
#
#
# 	spaCy1:
# 		0: Пример с "кавычками"
#
#
# 	spaCy2:
# 		0: Пример с "кавычками"
#
#
# 	spaCy3:
# 		0: Пример с "кавычками"
#
#
# 	stanza:
# 		0: Пример с "кавычками"
#
#
# 	Natasha:
# 		0: Пример с "кавычками"
#
#
# 	ru_sent_tokenize:
# 		0: Пример с "кавычками"
#
#
# -----------------------------------------------------------------------
# Пример со ссылками [1], [2, 3], и вот так[4]
#
# 	nltk:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# 	spaCy1:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# 	spaCy2:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# 	spaCy3:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# 	stanza:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# 	Natasha:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# 	ru_sent_tokenize:
# 		0: Пример со ссылками [1], [2, 3], и вот так[4]
#
#
# -----------------------------------------------------------------------
# Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н. Иванов, проф.Иванов
#
# 	nltk:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н.
# 		1: Иванов, проф.Иванов
#
#
# 	spaCy1:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н.
# 		1: Иванов, проф.
# 		2: Иванов
#
#
# 	spaCy2:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н.
# 		1: Иванов, проф.
# 		2: Иванов
#
#
# 	spaCy3:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н.
# 		1: Иванов, проф.
# 		2: Иванов
#
#
# 	stanza:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н. Иванов, проф.Иванов
#
#
# 	Natasha:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н. Иванов, проф.Иванов
#
#
# 	ru_sent_tokenize:
# 		0: Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н. Иванов, проф.Иванов
#
#
# -----------------------------------------------------------------------
# Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов, проф.иванов
#
# 	nltk:
# 		0: Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов, проф.иванов
#
#
# 	spaCy1:
# 		0: Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов,
# 		1: проф.иванов
#
#
# 	spaCy2:
# 		0: Это пример с именами строчными буквами: с.
# 		1: иванов, с.иванов, с.ю.
# 		2: иванов, с.ю.иванов, с.
# 		3: ю.
# 		4: иванов, сергей ю.
# 		5: иванов, сергей ю.иванов, проф.
# 		6: иванов, проф.иванов
#
#
# 	spaCy3:
# 		0: Это пример с именами строчными буквами: с.
# 		1: иванов, с.иванов, с.ю.
# 		2: иванов, с.ю.иванов, с.
# 		3: ю.
# 		4: иванов, сергей ю.
# 		5: иванов, сергей ю.иванов, проф.
# 		6: иванов, проф.иванов
#
#
# 	stanza:
# 		0: Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов, проф.иванов
#
#
# 	Natasha:
# 		0: Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов, проф.иванов
#
#
# 	ru_sent_tokenize:
# 		0: Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю.
# 		1: иванов, сергей ю.
# 		2: иванов, сергей ю.иванов, проф.
# 		3: иванов, проф.иванов
#
#
# -----------------------------------------------------------------------
# Пример с
#  переносом
#
# 	nltk:
# 		0: Пример с
#  переносом
#
#
# 	spaCy1:
# 		0: Пример с
#  переносом
#
#
# 	spaCy2:
# 		0: Пример с
#  переносом
#
#
# 	spaCy3:
# 		0: Пример с
#  переносом
#
#
# 	stanza:
# 		0: Пример с
#  переносом
#
#
# 	Natasha:
# 		0: Пример с
#  переносом
#
#
# 	ru_sent_tokenize:
# 		0: Пример с
#  переносом
#
#
# -----------------------------------------------------------------------
# Пример с многоточием... Между предложениями...
#
# 	nltk:
# 		0: Пример с многоточием... Между предложениями...
#
#
# 	spaCy1:
# 		0: Пример с многоточием...
# 		1: Между предложениями...
#
#
# 	spaCy2:
# 		0: Пример с многоточием...
# 		1: Между предложениями...
#
#
# 	spaCy3:
# 		0: Пример с многоточием... Между предложениями...
#
#
# 	stanza:
# 		0: Пример с многоточием...
# 		1: Между предложениями..
# 		2: .
#
#
# 	Natasha:
# 		0: Пример с многоточием...
# 		1: Между предложениями...
#
#
# 	ru_sent_tokenize:
# 		0: Пример с многоточием...
# 		1: Между предложениями...
#
#
# -----------------------------------------------------------------------
# Другой пример с многоточием...без пробелов... и с ними.
#
# 	nltk:
# 		0: Другой пример с многоточием...без пробелов... и с ними.
#
#
# 	spaCy1:
# 		0: Другой пример с многоточием...без пробелов... и с ними.
#
#
# 	spaCy2:
# 		0: Другой пример с многоточием...
# 		1: без пробелов... и с ними.
#
#
# 	spaCy3:
# 		0: Другой пример с многоточием...без пробелов... и с ними.
#
#
# 	stanza:
# 		0: Другой пример с многоточием...без пробелов... и с ними.
#
#
# 	Natasha:
# 		0: Другой пример с многоточием...без пробелов... и с ними.
#
#
# 	ru_sent_tokenize:
# 		0: Другой пример с многоточием...без пробелов... и с ними.
#
#
# -----------------------------------------------------------------------
# Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
# 	nltk:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# 	spaCy1:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# 	spaCy2:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# 	spaCy3:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# 	stanza:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# 	Natasha:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# 	ru_sent_tokenize:
# 		0: Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
#
# -----------------------------------------------------------------------
# Дефисы (или минус) -слева и справа-
#
# 	nltk:
# 		0: Дефисы (или минус) -слева и справа-
#
#
# 	spaCy1:
# 		0: Дефисы (или минус) -слева
# 		1: и справа-
#
#
# 	spaCy2:
# 		0: Дефисы (или минус) -слева и справа-
#
#
# 	spaCy3:
# 		0: Дефисы (или минус) -слева и справа-
#
#
# 	stanza:
# 		0: Дефисы (или минус) -слева и справа-
#
#
# 	Natasha:
# 		0: Дефисы (или минус) -слева и справа-
#
#
# 	ru_sent_tokenize:
# 		0: Дефисы (или минус) -слева и справа-
#
#
# -----------------------------------------------------------------------
# Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
# 	nltk:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	spaCy1:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	spaCy2:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	spaCy3:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	stanza:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	Natasha:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# 	ru_sent_tokenize:
# 		0: Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
#
# -----------------------------------------------------------------------
# @john: Это суууупер!!!!!! :))) :(
#
# 	nltk:
# 		0: @john: Это суууупер!!!!!!
# 		1: :))) :(
#
#
# 	spaCy1:
# 		0: @john: Это суууупер!!!!!!
# 		1: :))) :(
#
#
# 	spaCy2:
# 		0: @john: Это суууупер!!!!!
# 		1: !
# 		2: :))) :(
#
#
# 	spaCy3:
# 		0: @john: Это суууупер!!!!!! :))) :(
#
#
# 	stanza:
# 		0: @john:
# 		1: Это суууупер!!!!!! :))) :(
#
#
# 	Natasha:
# 		0: @john: Это суууупер!!!!!! :))) :(
#
#
# 	ru_sent_tokenize:
# 		0: @john: Это суууупер!!!!!!
# 		1: :))) :(
#
#
# -----------------------------------------------------------------------
# Классный ресторан :) Обязательно приду ещё раз!
#
# 	nltk:
# 		0: Классный ресторан :) Обязательно приду ещё раз!
#
#
# 	spaCy1:
# 		0: Классный ресторан :) Обязательно приду ещё раз!
#
#
# 	spaCy2:
# 		0: Классный ресторан :) Обязательно приду ещё раз!
#
#
# 	spaCy3:
# 		0: Классный ресторан :) Обязательно приду ещё раз!
#
#
# 	stanza:
# 		0: Классный ресторан :)
# 		1: Обязательно приду ещё раз!
#
#
# 	Natasha:
# 		0: Классный ресторан :)
# 		1: Обязательно приду ещё раз!
#
#
# 	ru_sent_tokenize:
# 		0: Классный ресторан :) Обязательно приду ещё раз!
#
#
# -----------------------------------------------------------------------
# Хороший маффин стоит 3,88
# в Нью-Йорке. Пожалуйста, купи мне... два.
#
# Спасибо.
#
# 	nltk:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2: Спасибо.
#
#
# 	spaCy1:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2:
#
# Спасибо.
#
#
# 	spaCy2:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2:
#
# Спасибо.
#
#
# 	spaCy3:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2:
#
# Спасибо.
#
#
# 	stanza:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2: Спасибо.
#
#
# 	Natasha:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2: Спасибо.
#
#
# 	ru_sent_tokenize:
# 		0: Хороший маффин стоит 3,88
# в Нью-Йорке.
# 		1: Пожалуйста, купи мне... два.
# 		2: Спасибо.
#
#
# -----------------------------------------------------------------------
# "Пример с прямой речью?" - говорит разработчик
#
# 	nltk:
# 		0: "Пример с прямой речью?"
# 		1: - говорит разработчик
#
#
# 	spaCy1:
# 		0: "Пример с прямой речью?" - говорит
# 		1: разработчик
#
#
# 	spaCy2:
# 		0: "Пример с прямой речью?"
# 		1: - говорит разработчик
#
#
# 	spaCy3:
# 		0: "Пример с прямой речью?" -
# 		1: говорит разработчик
#
#
# 	stanza:
# 		0: "Пример с прямой речью?" - говорит разработчик
#
#
# 	Natasha:
# 		0: "Пример с прямой речью?" - говорит разработчик
#
#
# 	ru_sent_tokenize:
# 		0: "Пример с прямой речью?" - говорит разработчик
#
#
# -----------------------------------------------------------------------
# Вот ещё один пример: "Тоже прямая речь, точка до кавычек." И следующее предложение.
#
# 	nltk:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек."
# 		1: И следующее предложение.
#
#
# 	spaCy1:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек.
# 		1: " И следующее предложение.
#
#
# 	spaCy2:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек.
# 		1: " И следующее предложение.
#
#
# 	spaCy3:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек."
# 		1: И следующее предложение.
#
#
# 	stanza:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек."
# 		1: И следующее предложение.
#
#
# 	Natasha:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек."
# 		1: И следующее предложение.
#
#
# 	ru_sent_tokenize:
# 		0: Вот ещё один пример: "Тоже прямая речь, точка до кавычек."
# 		1: И следующее предложение.
#
#
# -----------------------------------------------------------------------
# Третий пример: "Точка после кавычек". И следующее предложение.
#
# 	nltk:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# 	spaCy1:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# 	spaCy2:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# 	spaCy3:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# 	stanza:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# 	Natasha:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# 	ru_sent_tokenize:
# 		0: Третий пример: "Точка после кавычек".
# 		1: И следующее предложение.
#
#
# -----------------------------------------------------------------------
# 10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.
#
# 	nltk:
# 		0: 10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.
#
#
# 	spaCy1:
# 		0: 10 млн.
# 		1: руб. или долл.
# 		2: - точку не нужно ставить после "млн", но ставят.
#
#
# 	spaCy2:
# 		0: 10 млн.
# 		1: руб.
# 		2: или долл.
# 		3: - точку не нужно ставить после "млн", но ставят.
#
#
# 	spaCy3:
# 		0: 10 млн.
# 		1: руб.
# 		2: или долл. -
# 		3: точку не нужно ставить после "млн", но ставят.
#
#
# 	stanza:
# 		0: 10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.
#
#
# 	Natasha:
# 		0: 10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.
#
#
# 	ru_sent_tokenize:
# 		0: 10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.
#
#
# -----------------------------------------------------------------------
# Изъято 20 тыс. шт. патронов.
#
# 	nltk:
# 		0: Изъято 20 тыс. шт. патронов.
#
#
# 	spaCy1:
# 		0: Изъято 20 тыс. шт. патронов.
#
#
# 	spaCy2:
# 		0: Изъято 20 тыс.
# 		1: шт.
# 		2: патронов.
#
#
# 	spaCy3:
# 		0: Изъято 20 тыс.
# 		1: шт.
# 		2: патронов.
#
#
# 	stanza:
# 		0: Изъято 20 тыс. шт. патронов.
#
#
# 	Natasha:
# 		0: Изъято 20 тыс. шт. патронов.
#
#
# 	ru_sent_tokenize:
# 		0: Изъято 20 тыс. шт. патронов.
#
#
# -----------------------------------------------------------------------

# %% [markdown]
# ### Русский язык: токенизация

# %%
# spacy
nlp_spacy = spacy.load("ru_core_news_sm")

# stanza
nlp_stanza = stanza.Pipeline(lang='ru', processors='tokenize')
# Out:
# 2021-05-17 21:52:36 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# =========================
#
# 2021-05-17 21:52:36 INFO: Use device: gpu
# 2021-05-17 21:52:36 INFO: Loading: tokenize
# 2021-05-17 21:52:36 INFO: Done loading processors!

# %%
for text in texts_rus:
    
    print(f'{text}\n')
    
    # nltk
    print('\tnltk:')
    tokens_nltk = word_tokenize(text, language='russian')
    print(f'\t{tokens_nltk}')
    print('\n')
    
    # spaCy
    print('\tspaCy:')
    doc_spacy = nlp_spacy(text)
    tokens_spacy = [str(token) for token in doc_spacy]
    print(f'\t{tokens_spacy}')
    print('\n')
       
    # stanza
    print('\tstanza:')
    doc_stanza = nlp_stanza(text)
    tokens_stanza = []
    for sentence in doc_stanza.sentences:
        tokens_stanza += [token.text for token in sentence.tokens]
    print(f'\t{tokens_stanza}')
    print('\n')
    
    # Natasha
    print('\tNatasha:')
    tokens_natasha = []
    for sentence in sentenize(text):
        tokens_natasha += [token.text for token in tokenize(sentence.text)]
    print(f'\t{tokens_natasha}')
    print('\n')
    
    print('-----------------------------------------------------------------------')
# Out:
# Пример простого предложения
#
# 	nltk:
# 	['Пример', 'простого', 'предложения']
#
#
# 	spaCy:
# 	['Пример', 'простого', 'предложения']
#
#
# 	stanza:
# 	['Пример', 'простого', 'предложения']
#
#
# 	Natasha:
# 	['Пример', 'простого', 'предложения']
#
#
# -----------------------------------------------------------------------
# Пример простого предложения с точкой.
#
# 	nltk:
# 	['Пример', 'простого', 'предложения', 'с', 'точкой', '.']
#
#
# 	spaCy:
# 	['Пример', 'простого', 'предложения', 'с', 'точкой', '.']
#
#
# 	stanza:
# 	['Пример', 'простого', 'предложения', 'с', 'точкой', '.']
#
#
# 	Natasha:
# 	['Пример', 'простого', 'предложения', 'с', 'точкой', '.']
#
#
# -----------------------------------------------------------------------
# Тоже пример предложения, но с восклицательным знаком!
#
# 	nltk:
# 	['Тоже', 'пример', 'предложения', ',', 'но', 'с', 'восклицательным', 'знаком', '!']
#
#
# 	spaCy:
# 	['Тоже', 'пример', 'предложения', ',', 'но', 'с', 'восклицательным', 'знаком', '!']
#
#
# 	stanza:
# 	['Тоже', 'пример', 'предложения', ',', 'но', 'с', 'восклицательным', 'знаком', '!']
#
#
# 	Natasha:
# 	['Тоже', 'пример', 'предложения', ',', 'но', 'с', 'восклицательным', 'знаком', '!']
#
#
# -----------------------------------------------------------------------
# Первое предложение. Второе предложение.
#
# 	nltk:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', '.']
#
#
# 	spaCy:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', '.']
#
#
# 	stanza:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', '.']
#
#
# 	Natasha:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', '.']
#
#
# -----------------------------------------------------------------------
# Первое предложение.Второе предложение без пробела.
#
# 	nltk:
# 	['Первое', 'предложение.Второе', 'предложение', 'без', 'пробела', '.']
#
#
# 	spaCy:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', 'без', 'пробела', '.']
#
#
# 	stanza:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', 'без', 'пробела', '.']
#
#
# 	Natasha:
# 	['Первое', 'предложение', '.', 'Второе', 'предложение', 'без', 'пробела', '.']
#
#
# -----------------------------------------------------------------------
# У этого предложения в конце нет точки
#
# 	nltk:
# 	['У', 'этого', 'предложения', 'в', 'конце', 'нет', 'точки']
#
#
# 	spaCy:
# 	['У', 'этого', 'предложения', 'в', 'конце', 'нет', 'точки']
#
#
# 	stanza:
# 	['У', 'этого', 'предложения', 'в', 'конце', 'нет', 'точки']
#
#
# 	Natasha:
# 	['У', 'этого', 'предложения', 'в', 'конце', 'нет', 'точки']
#
#
# -----------------------------------------------------------------------
# В этом предложении есть апостроф' и двойной  пробел.
#
# 	nltk:
# 	['В', 'этом', 'предложении', 'есть', 'апостроф', "'", 'и', 'двойной', 'пробел', '.']
#
#
# 	spaCy:
# 	['В', 'этом', 'предложении', 'есть', 'апостроф', "'", 'и', 'двойной', ' ', 'пробел', '.']
#
#
# 	stanza:
# 	['В', 'этом', 'предложении', 'есть', "апостроф'", 'и', 'двойной', 'пробел.']
#
#
# 	Natasha:
# 	['В', 'этом', 'предложении', 'есть', 'апостроф', "'", 'и', 'двойной', 'пробел', '.']
#
#
# -----------------------------------------------------------------------
# Пример с "кавычками"
#
# 	nltk:
# 	['Пример', 'с', '``', 'кавычками', "''"]
#
#
# 	spaCy:
# 	['Пример', 'с', '"', 'кавычками', '"']
#
#
# 	stanza:
# 	['Пример', 'с', '"', 'кавычками', '"']
#
#
# 	Natasha:
# 	['Пример', 'с', '"', 'кавычками', '"']
#
#
# -----------------------------------------------------------------------
# Пример со ссылками [1], [2, 3], и вот так[4]
#
# 	nltk:
# 	['Пример', 'со', 'ссылками', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'и', 'вот', 'так', '[', '4', ']']
#
#
# 	spaCy:
# 	['Пример', 'со', 'ссылками', '[', '1', ']', ',', '[', '2', ',', '3', ']', ',', 'и', 'вот', 'так[4', ']']
#
#
# 	stanza:
# 	['Пример', 'со', 'ссылками', '[', '1', ']', ',', '[2', ',', '3', ']', ',', 'и', 'вот', 'так', '[4]']
#
#
# 	Natasha:
# 	['Пример', 'со', 'ссылками', '[', '1', ']', ',', '[', '2,', '3', ']', ',', 'и', 'вот', 'так', '[', '4', ']']
#
#
# -----------------------------------------------------------------------
# Это пример с именами: С. Иванов, С.Иванов, С.Ю. Иванов, С.Ю.Иванов, С. Ю. Иванов, Сергей Ю. Иванов, Сергей Ю.Иванов, к.п.н. Иванов, проф.Иванов
#
# 	nltk:
# 	['Это', 'пример', 'с', 'именами', ':', 'С.', 'Иванов', ',', 'С.Иванов', ',', 'С.Ю.', 'Иванов', ',', 'С.Ю.Иванов', ',', 'С.', 'Ю.', 'Иванов', ',', 'Сергей', 'Ю.', 'Иванов', ',', 'Сергей', 'Ю.Иванов', ',', 'к.п.н', '.', 'Иванов', ',', 'проф.Иванов']
#
#
# 	spaCy:
# 	['Это', 'пример', 'с', 'именами', ':', 'С.', 'Иванов', ',', 'С.Иванов', ',', 'С.Ю.', 'Иванов', ',', 'С.Ю.Иванов', ',', 'С.', 'Ю.', 'Иванов', ',', 'Сергей', 'Ю.', 'Иванов', ',', 'Сергей', 'Ю.Иванов', ',', 'к.п.н', '.', 'Иванов', ',', 'проф', '.', 'Иванов']
#
#
# 	stanza:
# 	['Это', 'пример', 'с', 'именами', ':', 'С.', 'Иванов', ',', 'С.', 'Иванов', ',', 'С.', 'Ю.', 'Иванов', ',', 'С.', 'Ю.', 'Иванов', ',', 'С.', 'Ю.', 'Иванов', ',', 'Сергей', 'Ю.', 'Иванов', ',', 'Сергей', 'Ю.', 'Иванов', ',', 'к.п.н.', 'Иванов', ',', 'проф.', 'Иванов']
#
#
# 	Natasha:
# 	['Это', 'пример', 'с', 'именами', ':', 'С', '.', 'Иванов', ',', 'С', '.', 'Иванов', ',', 'С', '.', 'Ю', '.', 'Иванов', ',', 'С', '.', 'Ю', '.', 'Иванов', ',', 'С', '.', 'Ю', '.', 'Иванов', ',', 'Сергей', 'Ю', '.', 'Иванов', ',', 'Сергей', 'Ю', '.', 'Иванов', ',', 'к', '.', 'п', '.', 'н', '.', 'Иванов', ',', 'проф', '.', 'Иванов']
#
#
# -----------------------------------------------------------------------
# Это пример с именами строчными буквами: с. иванов, с.иванов, с.ю. иванов, с.ю.иванов, с. ю. иванов, сергей ю. иванов, сергей ю.иванов, проф. иванов, проф.иванов
#
# 	nltk:
# 	['Это', 'пример', 'с', 'именами', 'строчными', 'буквами', ':', 'с.', 'иванов', ',', 'с.иванов', ',', 'с.ю.', 'иванов', ',', 'с.ю.иванов', ',', 'с.', 'ю.', 'иванов', ',', 'сергей', 'ю.', 'иванов', ',', 'сергей', 'ю.иванов', ',', 'проф.', 'иванов', ',', 'проф.иванов']
#
#
# 	spaCy:
# 	['Это', 'пример', 'с', 'именами', 'строчными', 'буквами', ':', 'с', '.', 'иванов', ',', 'с.иванов', ',', 'с.ю', '.', 'иванов', ',', 'с.ю.иванов', ',', 'с', '.', 'ю', '.', 'иванов', ',', 'сергей', 'ю', '.', 'иванов', ',', 'сергей', 'ю.иванов', ',', 'проф', '.', 'иванов', ',', 'проф.иванов']
#
#
# 	stanza:
# 	['Это', 'пример', 'с', 'именами', 'строчными', 'буквами', ':', 'с.', 'иванов', ',', 'с.иванов', ',', 'с.ю.', 'иванов', ',', 'с.ю.иванов', ',', 'с.', 'ю.', 'иванов', ',', 'сергей', 'ю.', 'иванов', ',', 'сергей', 'ю.иванов', ',', 'проф.', 'иванов', ',', 'проф.иванов']
#
#
# 	Natasha:
# 	['Это', 'пример', 'с', 'именами', 'строчными', 'буквами', ':', 'с', '.', 'иванов', ',', 'с', '.', 'иванов', ',', 'с', '.', 'ю', '.', 'иванов', ',', 'с', '.', 'ю', '.', 'иванов', ',', 'с', '.', 'ю', '.', 'иванов', ',', 'сергей', 'ю', '.', 'иванов', ',', 'сергей', 'ю', '.', 'иванов', ',', 'проф', '.', 'иванов', ',', 'проф', '.', 'иванов']
#
#
# -----------------------------------------------------------------------
# Пример с
#  переносом
#
# 	nltk:
# 	['Пример', 'с', 'переносом']
#
#
# 	spaCy:
# 	['Пример', 'с', '\n ', 'переносом']
#
#
# 	stanza:
# 	['Пример', 'с', 'переносом']
#
#
# 	Natasha:
# 	['Пример', 'с', 'переносом']
#
#
# -----------------------------------------------------------------------
# Пример с многоточием... Между предложениями...
#
# 	nltk:
# 	['Пример', 'с', 'многоточием', '...', 'Между', 'предложениями', '...']
#
#
# 	spaCy:
# 	['Пример', 'с', 'многоточием', '...', 'Между', 'предложениями', '...']
#
#
# 	stanza:
# 	['Пример', 'с', 'многоточием', '.', '.', '.', 'Между', 'предложениями', '.', '.', '.']
#
#
# 	Natasha:
# 	['Пример', 'с', 'многоточием', '...', 'Между', 'предложениями', '...']
#
#
# -----------------------------------------------------------------------
# Другой пример с многоточием...без пробелов... и с ними.
#
# 	nltk:
# 	['Другой', 'пример', 'с', 'многоточием', '...', 'без', 'пробелов', '...', 'и', 'с', 'ними', '.']
#
#
# 	spaCy:
# 	['Другой', 'пример', 'с', 'многоточием', '...', 'без', 'пробелов', '...', 'и', 'с', 'ними', '.']
#
#
# 	stanza:
# 	['Другой', 'пример', 'с', 'многоточием', '.', '.', '.без', 'пробелов', '.', '.', '.', 'и', 'с', 'ними', '.']
#
#
# 	Natasha:
# 	['Другой', 'пример', 'с', 'многоточием', '...', 'без', 'пробелов', '...', 'и', 'с', 'ними', '.']
#
#
# -----------------------------------------------------------------------
# Пример с дефисами: Санкт-Петербург, Кирово-Чепецк, кирово-чепецк, как-нибудь, как-то, Какой-то, Кто-то.
#
# 	nltk:
# 	['Пример', 'с', 'дефисами', ':', 'Санкт-Петербург', ',', 'Кирово-Чепецк', ',', 'кирово-чепецк', ',', 'как-нибудь', ',', 'как-то', ',', 'Какой-то', ',', 'Кто-то', '.']
#
#
# 	spaCy:
# 	['Пример', 'с', 'дефисами', ':', 'Санкт', '-', 'Петербург', ',', 'Кирово', '-', 'Чепецк', ',', 'кирово', '-', 'чепецк', ',', 'как', '-', 'нибудь', ',', 'как', '-', 'то', ',', 'Какой', '-', 'то', ',', 'Кто', '-', 'то', '.']
#
#
# 	stanza:
# 	['Пример', 'с', 'дефисами', ':', 'Санкт-Петербург', ',', 'Кирово-Чепецк', ',', 'кирово', '-', 'чепецк', ',', 'как-нибудь', ',', 'как-то', ',', 'Какой-то', ',', 'Кто-то', '.']
#
#
# 	Natasha:
# 	['Пример', 'с', 'дефисами', ':', 'Санкт-Петербург', ',', 'Кирово-Чепецк', ',', 'кирово-чепецк', ',', 'как-нибудь', ',', 'как-то', ',', 'Какой-то', ',', 'Кто-то', '.']
#
#
# -----------------------------------------------------------------------
# Дефисы (или минус) -слева и справа-
#
# 	nltk:
# 	['Дефисы', '(', 'или', 'минус', ')', '-слева', 'и', 'справа-']
#
#
# 	spaCy:
# 	['Дефисы', '(', 'или', 'минус', ')', '-слева', 'и', 'справа-']
#
#
# 	stanza:
# 	['Дефисы', '(', 'или', 'минус', ')', '-', 'слева', 'и', 'справа', '-']
#
#
# 	Natasha:
# 	['Дефисы', '(', 'или', 'минус', ')', '-', 'слева', 'и', 'справа', '-']
#
#
# -----------------------------------------------------------------------
# Числа: 1, 2.0, 3,5, 4,000, 5.000.000, 6,000,000, 7$, $8, 9.0$, $10.5, 11%, 12.5%
#
# 	nltk:
# 	['Числа', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# 	spaCy:
# 	['Числа', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# 	stanza:
# 	['Числа', ':', '1', ',', '2.0', ',', '3,5', ',', '4,000', ',', '5.000.000', ',', '6,000,000', ',', '7', '$', ',', '$', '8', ',', '9.0', '$', ',', '$', '10.5', ',', '11', '%', ',', '12.5', '%']
#
#
# 	Natasha:
# 	['Числа', ':', '1,', '2.0,', '3,5,', '4,000,', '5.000.000,', '6,000,000,', '7', '$', ',', '$', '8,', '9.0', '$', ',', '$', '10.5,', '11', '%', ',', '12.5', '%']
#
#
# -----------------------------------------------------------------------
# @john: Это суууупер!!!!!! :))) :(
#
# 	nltk:
# 	['@', 'john', ':', 'Это', 'суууупер', '!', '!', '!', '!', '!', '!', ':', ')', ')', ')', ':', '(']
#
#
# 	spaCy:
# 	['@john', ':', 'Это', 'суууупер', '!', '!', '!', '!', '!', '!', ':)))', ':(']
#
#
# 	stanza:
# 	['@john', ':', 'Это', 'суууупер', '!', '!', '!', '!', '!', '!', ':', ')', ')', ')', ':', '(']
#
#
# 	Natasha:
# 	['@', 'john', ':', 'Это', 'суууупер', '!!!!!!', ':)))', ':(']
#
#
# -----------------------------------------------------------------------
# Классный ресторан :) Обязательно приду ещё раз!
#
# 	nltk:
# 	['Классный', 'ресторан', ':', ')', 'Обязательно', 'приду', 'ещё', 'раз', '!']
#
#
# 	spaCy:
# 	['Классный', 'ресторан', ':)', 'Обязательно', 'приду', 'ещё', 'раз', '!']
#
#
# 	stanza:
# 	['Классный', 'ресторан', ':', ')', 'Обязательно', 'приду', 'ещё', 'раз', '!']
#
#
# 	Natasha:
# 	['Классный', 'ресторан', ':)', 'Обязательно', 'приду', 'ещё', 'раз', '!']
#
#
# -----------------------------------------------------------------------
# Хороший маффин стоит 3,88
# в Нью-Йорке. Пожалуйста, купи мне... два.
#
# Спасибо.
#
# 	nltk:
# 	['Хороший', 'маффин', 'стоит', '3,88', 'в', 'Нью-Йорке', '.', 'Пожалуйста', ',', 'купи', 'мне', '...', 'два', '.', 'Спасибо', '.']
#
#
# 	spaCy:
# 	['Хороший', 'маффин', 'стоит', '3,88', '\n', 'в', 'Нью', '-', 'Йорке', '.', 'Пожалуйста', ',', 'купи', 'мне', '...', 'два', '.', '\n\n', 'Спасибо', '.']
#
#
# 	stanza:
# 	['Хороший', 'маффин', 'стоит', '3,88', 'в', 'Нью-Йорке', '.', 'Пожалуйста', ',', 'купи', 'мне', '.', '.', '.', 'два', '.', 'Спасибо', '.']
#
#
# 	Natasha:
# 	['Хороший', 'маффин', 'стоит', '3,88', 'в', 'Нью-Йорке', '.', 'Пожалуйста', ',', 'купи', 'мне', '...', 'два', '.', 'Спасибо', '.']
#
#
# -----------------------------------------------------------------------
# "Пример с прямой речью?" - говорит разработчик
#
# 	nltk:
# 	['``', 'Пример', 'с', 'прямой', 'речью', '?', "''", '-', 'говорит', 'разработчик']
#
#
# 	spaCy:
# 	['"', 'Пример', 'с', 'прямой', 'речью', '?', '"', '-', 'говорит', 'разработчик']
#
#
# 	stanza:
# 	['"', 'Пример', 'с', 'прямой', 'речью', '?', '"', '-', 'говорит', 'разработчик']
#
#
# 	Natasha:
# 	['"', 'Пример', 'с', 'прямой', 'речью', '?', '"', '-', 'говорит', 'разработчик']
#
#
# -----------------------------------------------------------------------
# Вот ещё один пример: "Тоже прямая речь, точка до кавычек." И следующее предложение.
#
# 	nltk:
# 	['Вот', 'ещё', 'один', 'пример', ':', '``', 'Тоже', 'прямая', 'речь', ',', 'точка', 'до', 'кавычек', '.', "''", 'И', 'следующее', 'предложение', '.']
#
#
# 	spaCy:
# 	['Вот', 'ещё', 'один', 'пример', ':', '"', 'Тоже', 'прямая', 'речь', ',', 'точка', 'до', 'кавычек', '.', '"', 'И', 'следующее', 'предложение', '.']
#
#
# 	stanza:
# 	['Вот', 'ещё', 'один', 'пример', ':', '"', 'Тоже', 'прямая', 'речь', ',', 'точка', 'до', 'кавычек', '.', '"', 'И', 'следующее', 'предложение', '.']
#
#
# 	Natasha:
# 	['Вот', 'ещё', 'один', 'пример', ':', '"', 'Тоже', 'прямая', 'речь', ',', 'точка', 'до', 'кавычек', '.', '"', 'И', 'следующее', 'предложение', '.']
#
#
# -----------------------------------------------------------------------
# Третий пример: "Точка после кавычек". И следующее предложение.
#
# 	nltk:
# 	['Третий', 'пример', ':', '``', 'Точка', 'после', 'кавычек', "''", '.', 'И', 'следующее', 'предложение', '.']
#
#
# 	spaCy:
# 	['Третий', 'пример', ':', '"', 'Точка', 'после', 'кавычек', '"', '.', 'И', 'следующее', 'предложение', '.']
#
#
# 	stanza:
# 	['Третий', 'пример', ':', '"', 'Точка', 'после', 'кавычек', '"', '.', 'И', 'следующее', 'предложение', '.']
#
#
# 	Natasha:
# 	['Третий', 'пример', ':', '"', 'Точка', 'после', 'кавычек', '"', '.', 'И', 'следующее', 'предложение', '.']
#
#
# -----------------------------------------------------------------------
# 10 млн. руб. или долл. - точку не нужно ставить после "млн", но ставят.
#
# 	nltk:
# 	['10', 'млн.', 'руб.', 'или', 'долл.', '-', 'точку', 'не', 'нужно', 'ставить', 'после', '``', 'млн', "''", ',', 'но', 'ставят', '.']
#
#
# 	spaCy:
# 	['10', 'млн', '.', 'руб', '.', 'или', 'долл', '.', '-', 'точку', 'не', 'нужно', 'ставить', 'после', '"', 'млн', '"', ',', 'но', 'ставят', '.']
#
#
# 	stanza:
# 	['10', 'млн', '.', 'руб', '.', 'или', 'долл', '.', '-', 'точку', 'не', 'нужно', 'ставить', 'после', '"', 'млн', '"', ',', 'но', 'ставят', '.']
#
#
# 	Natasha:
# 	['10', 'млн', '.', 'руб', '.', 'или', 'долл', '.', '-', 'точку', 'не', 'нужно', 'ставить', 'после', '"', 'млн', '"', ',', 'но', 'ставят', '.']
#
#
# -----------------------------------------------------------------------
# Изъято 20 тыс. шт. патронов.
#
# 	nltk:
# 	['Изъято', '20', 'тыс.', 'шт.', 'патронов', '.']
#
#
# 	spaCy:
# 	['Изъято', '20', 'тыс', '.', 'шт', '.', 'патронов', '.']
#
#
# 	stanza:
# 	['Изъято', '20', 'тыс', '.', 'шт.', 'патронов', '.']
#
#
# 	Natasha:
# 	['Изъято', '20', 'тыс', '.', 'шт', '.', 'патронов', '.']
#
#
# -----------------------------------------------------------------------
